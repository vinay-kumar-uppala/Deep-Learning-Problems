# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay-kumar-uppala/Deep-Learning-Problems/blob/feature%2Fversion-one/Placement_Data_Full_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Placement_data_full_class.csv')

# %%
df.shape
# Out:
# (215, 15)

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
from sklearn.model_selection import train_test_split

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
X=df.iloc[:,[2,4,7,10,12]]
X
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p
# 0    67.00  91.00     58.00     55.0  58.80
# 1    79.33  78.33     77.48     86.5  66.28
# 2    65.00  68.00     64.00     75.0  57.80
# 3    56.00  52.00     52.00     66.0  59.43
# 4    85.80  73.60     73.30     96.8  55.50
# ..     ...    ...       ...      ...    ...
# 210  80.60  82.00     77.60     91.0  74.49
# 211  58.00  60.00     72.00     74.0  53.62
# 212  67.00  67.00     73.00     59.0  69.72
# 213  74.00  66.00     58.00     70.0  60.23
# 214  62.00  58.00     53.00     89.0  60.22
#
# [215 rows x 5 columns]

# %%
y=df.iloc[:,-2]
y=y.replace('Placed',1)
y=y.replace('Not Placed',0)
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 210    1
# 211    1
# 212    1
# 213    1
# 214    0
# Name: status, Length: 215, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (172, 5)

# %%
y_test
# Out:
# 108    1
# 207    1
# 106    0
# 107    1
# 51     0
# 33     1
# 59     1
# 152    1
# 4      1
# 31     0
# 118    1
# 39     1
# 93     0
# 69     1
# 161    0
# 112    1
# 94     1
# 97     0
# 151    1
# 38     1
# 44     1
# 200    1
# 84     1
# 18     0
# 158    0
# 35     1
# 73     1
# 122    1
# 19     1
# 62     1
# 169    0
# 181    0
# 34     0
# 11     1
# 29     0
# 0      1
# 159    0
# 148    1
# 130    0
# 28     1
# 16     1
# 198    0
# 195    1
# Name: status, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-3.78024513e-01, -5.70062211e-01, -1.30846321e+00,
#          4.63818402e-01, -1.31487558e+00],
#        [ 2.50971498e-01, -2.94357512e-01, -5.05364754e-02,
#         -8.25989281e-01, -3.50624077e-01],
#        [-3.78024513e-01,  7.32487544e-02, -5.05364754e-02,
#         -3.07597676e-01, -7.70316279e-01],
#        [ 6.10397791e-01, -3.86259078e-01,  2.29002800e-01,
#          1.55251971e-01, -7.18288320e-01],
#        [ 9.69824083e-01,  9.92264419e-01,  1.90623845e+00,
#         -9.24730539e-01,  7.95725282e-01],
#        [ 9.40171414e-01, -1.20663551e-01,  6.02187733e-01,
#          1.31237609e+00, -3.02064649e-01],
#        [-4.67881086e-01, -7.53865344e-01, -1.86754177e+00,
#          1.31237609e+00, -3.31547159e-01],
#        [-1.27659024e+00, -2.94357512e-01, -8.89154302e-01,
#         -1.53314461e-01, -1.54900140e+00],
#        [ 1.50896352e+00,  2.26969619e+00, -2.60190932e-01,
#          1.08403693e+00, -4.70288383e-01],
# ...

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(3,activation='relu',input_dim=5))

# %%
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 3)                 18
#
#  dense_4 (Dense)             (None, 1)                 4
#
# ...
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 3)                 18
#
# ...
# Total params: 18
# Trainable params: 18
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer='Adam')

# %%
history= model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1121
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1116
# Epoch 3/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1112
# Epoch 4/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1107
# Epoch 5/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1103
# Epoch 6/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1100
# Epoch 7/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1096
# Epoch 8/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 9/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1089
# Epoch 10/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1085
# Epoch 11/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1083
# Epoch 12/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1079
# ...

# %%
y_log=model.predict(X_test_scaled)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
y_pred=np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8604651162790697

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
